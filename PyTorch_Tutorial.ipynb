# %% [markdown]
# <a href="https://colab.research.google.com/github/JeremyKlauber/PyTorch-Intro/blob/main/PyTorch_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
